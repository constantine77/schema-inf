# %%
access_key = "<access_key>"
secret_key = "<secret_key>"
sc._jsc.hadoopConfiguration().set("fs.s3a.access.key", access_key)
sc._jsc.hadoopConfiguration().set("fs.s3a.secret.key", secret_key)

dbutils.fs.ls("<s3_uri>")
# Out:
# Out[1]: [FileInfo(path='s3://databricks-workspace-stack-lambdazipsbucket-jfutdmhao6c/data/', name='data/', size=0, modificationTime=1667093097834),
#  FileInfo(path='s3://databricks-workspace-stack-lambdazipsbucket-jfutdmhao6c/functions/', name='functions/', size=0, modificationTime=1667093097834),
#  FileInfo(path='s3://databricks-workspace-stack-lambdazipsbucket-jfutdmhao6c/schemas/', name='schemas/', size=0, modificationTime=1667093097834)]

# %%
### Uncomment .transform on readStream to fix column naming error.
# def remove_bda_chars_from_columns(df):
#     return  df.select([df[x].alias(x.replace(" ", "_").replace("/", "").replace("%", "pct").replace("(", "").replace(")", "")) for x in df.columns])

# %%
(spark.readStream.format("cloudFiles")
  .option("cloudFiles.format", "json")
  .option("cloudFiles.schemaLocation", "<s3_uri>/schemas/")
  .load("s3://databricks-workspace-stack-lambdazipsbucket-jfutdmhao6c/data/") #.transform(lambda df: remove_bda_chars_from_columns(df))
  .writeStream
  .option("checkpointLocation", "<s3_uri>/schemas/")
  .start("path_to_data")
)
(spark.readStream.format("cloudFiles")
  .option("cloudFiles.format", "csv")
  .option("cloudFiles.schemaLocation", "<s3_uri>/schemas/")
  .load("s3://databricks-workspace-stack-lambdazipsbucket-jfutdmhao6c/data/") #.transform(lambda df: remove_bda_chars_from_columns(df))
  .writeStream
  .option("checkpointLocation", "<s3_uri>/schemas/")
  .start("path_to_data")
)

(spark.readStream.format("cloudFiles")
  .option("cloudFiles.format", "parquet")
  .option("cloudFiles.schemaLocation", "<s3_uri>/schemas/")
  .load("s3://databricks-workspace-stack-lambdazipsbucket-jfutdmhao6c/data/") #.transform(lambda df: remove_bda_chars_from_columns(df))
  .writeStream
  .option("checkpointLocation", "<s3_uri>/schemas/")
  .start("path_to_data")
)

(spark.readStream.format("cloudFiles")
  .option("cloudFiles.format", "avro")
  .option("cloudFiles.schemaLocation", "<s3_uri>/schemas/")
  .load("s3://databricks-workspace-stack-lambdazipsbucket-jfutdmhao6c/data/") #.transform(lambda df: remove_bda_chars_from_columns(df))
  .writeStream
  .option("checkpointLocation", "<s3_uri>/schemas/")
  .start("path_to_data")
)
# Out:
# Out[12]: <pyspark.sql.streaming.query.StreamingQuery at 0x7f66cc061490>
